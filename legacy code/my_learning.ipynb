# %% [markdown]
# ### 1) Creating Classes
# - So for that its a matter of how the class will handle the df. The functions should all return the df back so there are 2 main ways you can go about this is to either have the df be a class attribute, e.g.
#
# ### Approach 1
#
# ![image.png](attachment:image.png)
#
# ### Approach 2
#
# ![image-2.png](attachment:image-2.png)
#
# - Thanks Jared this is really useful, I can see how the second approach can be good for classes with different types of method needed and I can add as I do my EDA.
